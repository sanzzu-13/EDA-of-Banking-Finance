# %% [markdown]
# # 📊💼 Analyzing Finance Data 💼📊

# %% [markdown]
# # Introduction

# %% [markdown]
# The notebook is based on the data from Kaggle, provided by the username NITIN DATTA, and the direct URL to the dataset is https://www.kaggle.com/datasets/nitindatta/finance-data. The dataset consists of 5 rows with 25 attributes:age,Investment_Avenuse, Mutual_Funds(Rank in order of preference), Equity_Market(Rank in order of preference), Debenture (Rank in order of preference), Government_Bonds (Rank in order of preference), Fixes_Deposites (Rank in order of preference), PPF(Rank in order of preference), Gold(Rank in order of preference), Stock_Market, Factor, Object, Purpose, Duration, Invest_Monitor, Expect, Avenue, What are you saving objectives?, Reaason_Equity, Reason_Mutual, Reason_Bonds, Reason_FD, Source.

# %%
import matplotlib.image as mpimg

# Path to your image
image_path = 'pic.png'

# Load the image
img = mpimg.imread(image_path)

# Display the image
plt.imshow(img)
plt.axis('off')  # Turn off axis
plt.show()

# %% [markdown]
# The  age,,mutual funds,equity market debenture government bonds, fixed depositeppf gold attribute, represented by the  intiger(numeric) all other attributes were continuous variables, and the memory size consumed by the dataset was 7.9kb.

# %%
# Path to your image
image_path = 'pic1.png'

# Load the image
img = mpimg.imread(image_path)

# Display the image
plt.imshow(img)
plt.axis('off')  # Turn off axis
plt.show()

# %% [markdown]
# * objective
#   - find the relation betweeen age and fixed deposite

# %%
#Importing necessary libraries
import pandas as pd  # pandas for data manipulation and analysis
import numpy as np  # numpy for numerical computing
import matplotlib.pyplot as plt  # matplotlib for plotting
# %matplotlib inline  
# This line is specific to Jupyter notebooks, it ensures that plots are displayed inline
import seaborn as sns  # seaborn for statistical data visualization

# %%
# Read the data file using pandas
df = pd.read_csv('Finance_data.csv')  # 'pd.read_csv()' function reads the CSV file named 'Finance_data.csv' and stores it in a pandas DataFrame called 'df'.

# %%
# Display the first few rows of the DataFrame
df.head()  # 'df.head()' displays the first five rows of the DataFrame 'df'.
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# ...

# %% [markdown]
# * Dataset contains 5 rows and 25 attributes.
# * Attributes include a mix of integer, float, and object data types.
# * Integer and float data types represent numerical values like counts, measurements, or scores.
# * Object data type typically represents categorical or textual data such as names, labels, or categories.
# * The dataset likely contains diverse information such as demographic details, financial metrics, or categorical labels.
# * Each row represents an observation or instance, while each attribute provides specific information about that observation.

# %% [markdown]
# Lets summarize the central tendency, dispersion and shape of dataset distribution

# %%
# Generate descriptive statistics of the DataFrame
df.describe()  # 'df.describe()' generates summary statistics of the numerical columns in the DataFrame 'df'
# Out:
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold
# count       40.000000  40.000000  40.000000
# mean         3.575000   2.025000   5.975000
# std          1.795828   1.609069   1.143263
# min          1.000000   1.000000   2.000000
# 25%          2.750000   1.000000   6.000000
# ...

# %% [markdown]
# - the mean of age is 27.80 and 3.575 are the mean of Fixed deposite
# - the standerd deviatio of age  is 3.56 and fixed deposite of 1.795
# - the min of age is 21.0 and fixed deposite  is 1.0

# %%
# Retrieve the shape of the DataFrame.
# This returns a tuple containing the number of rows and columns in the DataFrame.
df.shape
# Out:
# (40, 24)

# %%
# Display concise summary of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             40 non-null     object
#  1   age                                40 non-null     int64
#  2   Investment_Avenues                 40 non-null     object
#  3   Mutual_Funds                       40 non-null     int64
#  4   Equity_Market                      40 non-null     int64
#  5   Debentures                         40 non-null     int64
#  6   Government_Bonds                   40 non-null     int64
#  7   Fixed_Deposits                     40 non-null     int64
#  8   PPF                                40 non-null     int64
#  9   Gold                               40 non-null     int64
#  10  Stock_Marktet                      40 non-null     object
# ...

# %% [markdown]
# - There are 1 column of float64,8 columns of int64, 16 columns of object.
# - The total storage consumed by the data is 7.9 KB.

# %%
# Inspect missing values in the dataset
print(df.isnull().values.sum())

# Replace the ' 's with NaN
df = df.replace(" ",np.NaN)


# Impute the missing values with mean imputation
# df = df.fillna(df.mean())

# Count the number of NaNs in the dataset to verify
print(df.isnull().values.sum())
# Out:
# 0
# 0

# %% [markdown]
# * There are no missing values within this dataset all data  are complete.

# %%
# Create a histogram for the 'age' column
plt.hist(df['age'], bins=12, color='blue', edgecolor='black')

# Add title and labels to the plot
plt.title('Distribution of Age')
plt.xlabel('Age of Investor')
plt.ylabel('Count')


# Show the plot
plt.show()

# %% [markdown]
# * I has almost symmertic- ell shaped
# * The largest age group in this dataset falls between 20 and 30 years.
# * The ages are grouped in  5 years difference

# %%
# Create a histogram plot for the 'age' column
sns.histplot(df['age'], bins=15, color='skyblue', edgecolor='black')

# Add title and labels to the plot
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Count')

# Add vertical grid lines
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Customize ticks and labels
plt.xticks(range(0, 41, 5), fontsize=8)
plt.yticks(fontsize=8)

# Limit x-axis to 40
plt.xlim(0, 40)

# Add a legend
plt.legend(['Age'], loc='upper right')

# Show the plot
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# - We can observe that people age 25 to 30 are more active for  fixed deposit.
# - As people age beyond 30, there is a decrese  in fixed deposit activity.
# - Specially individuals age  27 is to engage more in fixed deposits.

# %%
# Create a scatter plot for 'Fixed_Deposits' against 'age'
sns.scatterplot(x=df['Fixed_Deposits'], y=df['age'], color='skyblue', alpha=0.7, edgecolor='black', s=80)

# Add title and labels to the plot
plt.title(' relation between Fixed Deposits and  Age')
plt.xlabel('Fixed Deposits')
plt.ylabel('Age')

# Customize ticks and labels
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.legend(['Fixed_Deposits'], loc='upper right')


# Show the plot
plt.show()

# %% [markdown]
# * People age is 30 and above generally show less interest in fixed deposits,when they participate, they  invest larger amounts.
# *
# Individuals ag of  22 and below are less active infixed g deposits
# *
# The age range between 25 and 3showinges higher activity in fixed deposit transacti.
# * In this dataset, individuals aged between 25 and showing bit the highest level of activity in fixed deposit investments.

# %%
# Create a line plot for 'Fixed_Deposits' against 'age'
sns.lineplot(x=df['age'], y=df['Fixed_Deposits'], color='skyblue', linewidth=2, marker='o', markersize=8)

# Add title and labels to the plot
plt.title(' Relation of Fixed Deposits and Age')
plt.xlabel('Age')
plt.ylabel('Fixed Deposits')

# Customize ticks and labels
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

# Show the plot
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# * The plot indicates that individuals aged 30 and above are less active in fixed deposit investments.
# * the data seen Despite being less active, individuals aged 30 and above tended to deposit higher amounts.
# * People aged between 26 and 30 seen  activity in fixed deposit investments, typically within a mediam range of amounts.
# * the data also seen Individuals age 22 and below also low activity in fixed deposit transactions..

# %%
# Define custom colors
custom_palette = ["blue", "gray"]  # Example custom colors

# Create a boxplot for 'age' with respect to 'gender' using custom colors
sns.boxplot(y='age', data=df, x='gender', palette=custom_palette)

# Add title and labels to the plot
plt.title('Age Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Age')

# Customize ticks and labels
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

# Show the plot
plt.show()

# %% [markdown]
# * The dataset shows contains more female data than male data.
# * Within the dataset, females aged between 24 and 31 are the most active age group.
# * Due to the leftward shift of the median line, the box plots for females shows right skewness.
# * Although tha data shows males aged between 26 and 30 are comparatively more numerous, their numbers are still lower than those of females.
# * Similarly, the box plots for males also demonstrate right skewness due to the leftward shift of the median line.
# * Overall, the dataset shows that females are more active in fixed deposit investments compared to males

# %%
df_numeric=df.apply(pd.to_numeric,errors='coerce')

# %%
# #this is heat map pearson correlation matrix
# corrmat = df_numeric.corr(numeric_only=True)
# f, ax = plt.subplots(figsize=(16, 12))
# sns.heatmap(corrmat, vmax=0.8, square=True);
# plt.title('Pearson Correlation Matrix Heatmap',fontsize=16)
# plt.show()
# df_coy = df.copy()
# selecting cols where the datatype is int64
selected_columns = [col for col in df.columns if df[col].dtype == 'int64']

# Creating new df with selected columns
new_df = df[selected_columns].copy()


print(new_df.head())
# Out:
#    age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# 0   34             1              2           5                 3
# 1   23             4              3           2                 1
# 2   30             3              6           4                 2
# 3   22             2              1           3                 7
# 4   24             2              1           3                 6
#
#    Fixed_Deposits  PPF  Gold
# 0               7    6     4
# 1               5    6     7
# 2               5    1     7
# 3               6    4     5
# 4               4    5     7

# %%
# Generate Pearson correlation matrix
corrmat = new_df.corr()

# Set up the plot figure
plt.figure(figsize=(12, 10))

# Create the heatmap using seaborn
sns.heatmap(corrmat, cmap='coolwarm', annot=True, fmt=".2f", linewidths=0.5)

# Add title
plt.title('Pearson Correlation Matrix Heatmap', fontsize=16)

# Rotate y-axis labels for better readability
plt.yticks(rotation=0)

# Show the plot
plt.show()

# %% [markdown]
# * The heatmap illustrates the correlation between fixed deposit and age.
# * There exists a weak negative correlation (-0.26) between age and fixed deposit.
# * where 1 is a perfect positive correlation and -1 is perfect negative correlation.
# * If the correlation value between age and fixed deposit is 0, it indicates no correlation between these two attribute.
# * indicating that age is not strongly related to fixed deposit activity.

# %% [markdown]
# # Finding:

# %% [markdown]
# * Dataset contains 5 rows and 25 attributes.Attributes include a mix of integer, float, and object data types.
# * Integer and float data types represent numerical values like counts, measurements, or scores.
# * Object data type typically represents categorical or textual data such as names, labels, or categories.
# * he dataset likely contains diverse information such as demographic details, financial metrics, or categorical labels.
# * Each row represents an observation or instance, while each attribute provides specific information about that observation.
# * the mean of age are 27.80 and 3.575 are the mean of Fixed deposite
# * the standerd deviatio of age is 3.56 and fixed deposite of 1.795
# * the min of age is 21.0 and fixed deposite is 1.0
# * There are 1 column of float64,8 columns of int64, 16 columns of object.
# * The total storage consumed by the data is 7.9 KB.
# * There are no missing values within this dataset all data are complete.
# * The largest age group in this dataset falls between 20 and 30 years.
# * The ages are grouped in 5 years difference
# * We can observe that people age 25 to 30 are more active for fixed deposit.
# * As people age beyond 30, there is a decrese in fixed deposit activity.
# * Specially individuals age 27 is to engage more in fixed deposits.
# * People age is 30 and above generally show less interest in fixed deposits,when they participate, they invest larger amounts.
# * Individuals ag of 22 and below are less active in fixed deposits
# * The age range between 25 and 3showinges higher activity in fixed deposit transaction.
# * In this dataset, individuals aged between 25 and showing bit the highest level of activity in fixed deposit investments.
# *The plot indicates that individuals aged 30 and above are less active in fixed deposit investments.
# * the data seen Despite being less active, individuals aged 30 and above tended to deposit higher amounts.
# * People aged between 26 and 30 seen activity in fixed deposit investments, typically within a mediam range of amounts.
# * the data also seen Individuals age 22 and below also low activity in fixed deposit transactionshe dataset shows contains more female data than male data.
# * Within the dataset, females aged between 24 and 31 are the most active age group.
# * Due to the leftward shift of the median line, the box plots for females shows right skewness.
# * Although tha data shows males aged between 26 and 30 are comparatively more numerous, their numbers are still lower than those of females.
# * Similarly, the box plots for males also demonstrate right skewness due to the leftward shift of the median line.
# * Overall, the dataset shows that females are more active in fixed deposit investments compared to males
# * The heatmap illustrates the correlation between fixed deposit and age.
# *
# There exists a weak negative correlation (-0.26) between age and fixed deposit.*
# where 1 is a perfect positive correlation and -1 is perfect negative correlation* .
# If the correlation value between age and fixed deposit is 0, it indicates no correlation between these two attribut* e.
# indicating that age is not strongly related to fixed deposit activ
# ity.

# %% [markdown]
# # Age weakly influences fixed deposit activity; other factors like financial literacy and income are more significant determinants.

# %% [markdown]
# ### Exploratory Data Analysis By Sanjaya Kumar Giri
